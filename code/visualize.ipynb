# %%
import numpy as np
import pandas as pd
import scipy as sp

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train_path = '../dataset/train.csv'

# %%
train_df = pd.read_csv(train_path, parse_dates=['record_date'])

# %%
train_df.power_consumption.mean()
# Out:
# 2617.602554332851

# %%
train_df.groupby('record_date')['power_consumption'].mean().plot()

# %%
train_df.loc[train_df.user_id==4].set_index('record_date')['power_consumption'].plot()
