# %%
import numpy as np
import pandas as pd
import scipy as sp

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train_path = '../dataset/train.csv'

# %%
train_df = pd.read_csv(train_path, parse_dates=['record_date'])

# %%
train_df.power_consumption.mean()
# Out:
# 2617.602554332851

# %%
train_df.groupby('record_date')['power_consumption'].mean().plot()

# %%
train_df.loc[train_df.user_id ==1]
# Out:
#        record_date  user_id  power_consumption
# 0       2015-01-01        1               1135
# 1       2015-01-02        1                570
# 2       2015-01-03        1               3418
# 3       2015-01-04        1               3968
# 4       2015-01-05        1               3986
# 5       2015-01-06        1               4082
# 6       2015-01-07        1               4172
# 7       2015-01-08        1               4022
# 8       2015-01-09        1               4025
# 9       2015-01-10        1               4047
# 10      2015-01-11        1               4135
# 11      2015-01-12        1               4111
# 12      2015-01-13        1               3926
# 13      2015-01-14        1               4244
# 14      2015-01-15        1               4144
# 15      2015-01-16        1               4269
# 16      2015-01-17        1               4262
# 17      2015-01-18        1               2782
# 18      2015-01-19        1               3327
# 19      2015-01-20        1               4002
# 20      2015-01-21        1               3925
# 21      2015-01-22        1               3813
# 22      2015-01-23        1               4293
# 23      2015-01-24        1               4205
# 24      2015-01-25        1               4162
# 25      2015-01-26        1               3917
# 26      2015-01-27        1               4007
# 27      2015-01-28        1               4060
# 28      2015-01-29        1               4045
# 29      2015-01-30        1               4162
# ...            ...      ...                ...
# 893762  2016-09-15        1                 43
# 900468  2016-09-07        1                148
# 901179  2016-09-25        1                162
# 903317  2016-09-30        1                206
# 903366  2016-09-04        1                207
# 903706  2016-09-16        1                214
# 904180  2016-09-11        1                225
# 905427  2016-09-23        1                260
# 906382  2016-09-26        1                286
# 907083  2016-09-22        1                304
# 907412  2016-09-24        1                312
# 908005  2016-09-29        1                330
# 908212  2016-09-05        1                335
# 908414  2016-09-08        1                342
# 908481  2016-09-20        1                344
# 908788  2016-09-21        1                353
# 908828  2016-09-19        1                354
# 910244  2016-09-18        1                399
# 910617  2016-09-12        1                412
# 910669  2016-09-14        1                415
# 910762  2016-09-17        1                418
# 910826  2016-09-28        1                420
# 911133  2016-09-10        1                431
# 911338  2016-09-27        1                440
# 911696  2016-09-09        1                453
# 912043  2016-09-06        1                467
# 912074  2016-09-01        1                469
# 912148  2016-09-02        1                472
# 912494  2016-09-13        1                488
# 913585  2016-09-03        1                542
#
# [639 rows x 3 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929088 entries, 0 to 929087
# Data columns (total 3 columns):
# record_date          929088 non-null datetime64[ns]
# user_id              929088 non-null int64
# power_consumption    929088 non-null int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 21.3 MB

# %%
train_df.loc[train_df.power_consumption<10].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171312 entries, 673 to 890945
# Data columns (total 3 columns):
# record_date          171312 non-null datetime64[ns]
# user_id              171312 non-null int64
# power_consumption    171312 non-null int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 5.2 MB

# %%
train_df.power_consumption.value_counts()
# Out:
# 1          148424
# 2            5928
# 4            3509
# 10           2813
# 7            2750
# 9            2747
# 5            2747
# 12           2740
# 11           2680
# 8            2620
# 3            2587
# 14           2567
# 16           2468
# 13           2466
# 15           2408
# 18           2263
# 19           2211
# 22           2039
# 21           2011
# 20           1993
# 23           1958
# 27           1934
# 26           1893
# 25           1877
# 24           1850
# 30           1782
# 31           1722
# 29           1720
# 51           1704
# 46           1655
#             ...
# 97491           1
# 1162443         1
# 186803          1
# 23287           1
# 187046          1
# 107209          1
# 84692           1
# 21239           1
# 1195193         1
# 11003           1
# 15097           1
# 17142           1
# 88789           1
# 358993          1
# 12258           1
# 18679           1
# 20724           1
# 30961           1
# 16122           1
# 24310           1
# 20212           1
# 48874           1
# 77528           1
# 83669           1
# 576996          1
# 1070327         1
# 1050784         1
# 13051           1
# 11000           1
# 11514           1
# Name: power_consumption, dtype: int64
